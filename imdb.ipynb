# %%
import pandas as pd

# %%
data=pd.read_csv('IMDB show ratings.csv')
data
# Out:
#       Rank                        Name  Year of Release  IMDB rating
# 0        1             Planet Earth II             2016          9.4
# 1        2                Breaking Bad             2008          9.4
# 2        3                Planet Earth             2006          9.4
# 3        4            Band of Brothers             2001          9.4
# 4        5                   Chernobyl             2019          9.3
# ..     ...                         ...              ...          ...
# 245    246                   The Knick             2014          8.4
# 246    247                     Gintama             2005          8.4
# 247    248  The Great British Bake Off             2010          8.4
# 248    249                 Black Books             2000          8.4
# 249    250                 Foyle's War             2002          8.4
#
# [250 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0    Rank            250 non-null    int64
#  1   Name             250 non-null    object
#  2   Year of Release  250 non-null    int64
#  3   IMDB rating      250 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 7.9+ KB

# %%
data['Year of Release'].unique()
# Out:
# array([2016, 2008, 2006, 2001, 2019, 2002, 2017, 2005, 2014, 1999, 1980,
#        2011, 1973, 2013, 2023, 2009, 2020, 2010, 1959, 2018, 1992, 2021,
#        1981, 2015, 1990, 1989, 1998, 2012, 1994, 1969, 1985, 2000, 1975,
#        1995, 2003, 1976, 1997, 2004, 2022, 2007, 1987, 1984, 1988, 1993,
#        1986, 1960, 1972, 1955], dtype=int64)

# %%
data.describe()
# Out:
#              Rank  Year of Release  IMDB rating
# count  250.000000       250.000000   250.000000
# mean   125.500000      2006.928000     8.653200
# std     72.312977        12.512597     0.220099
# min      1.000000      1955.000000     8.400000
# 25%     63.250000      2001.000000     8.500000
# 50%    125.500000      2010.000000     8.600000
# 75%    187.750000      2016.000000     8.800000
# max    250.000000      2023.000000     9.400000

# %%
data.isnull()
# Out:
#       Rank   Name  Year of Release  IMDB rating
# 0    False  False            False        False
# 1    False  False            False        False
# 2    False  False            False        False
# 3    False  False            False        False
# 4    False  False            False        False
# ..     ...    ...              ...          ...
# 245  False  False            False        False
# 246  False  False            False        False
# 247  False  False            False        False
# 248  False  False            False        False
# 249  False  False            False        False
#
# [250 rows x 4 columns]

# %%
data['Year of Release'].value_counts()
# Out:
# 2015    15
# 2014    14
# 2019    14
# 2016    11
# 2018    11
# 2010    11
# 2011    11
# 2004    11
# 2021     9
# 2017     9
# 2009     9
# 1989     8
# 2013     8
# 2022     8
# 2005     7
# 1999     7
# 2001     7
# 2003     7
# 2020     6
# 2006     6
# 1997     5
# 2012     5
# 2002     5
# 1986     4
# 1995     4
# 2000     3
# 1987     3
# 2007     3
# 1990     3
# 1998     3
# 2008     3
# 1980     2
# 1993     2
# 1988     2
# 1969     1
# 1973     1
# 1972     1
# 1960     1
# 1984     1
# 1959     1
# 2023     1
# 1985     1
# 1992     1
# 1981     1
# 1976     1
# 1975     1
# 1994     1
# 1955     1
# Name: Year of Release, dtype: int64

# %%
data['IMDB rating'].value_counts()
# Out:
# 8.5    74
# 8.6    56
# 8.7    28
# 8.4    28
# 8.9    21
# 8.8    19
# 9.0     8
# 9.2     6
# 9.4     4
# 9.1     4
# 9.3     2
# Name: IMDB rating, dtype: int64

# %%
data.corr()
# Out:
#                      Rank  Year of Release  IMDB rating
#  Rank            1.000000         0.080066    -0.901431
# Year of Release  0.080066         1.000000    -0.064225
# IMDB rating     -0.901431        -0.064225     1.000000

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")
sns.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
sns.heatmap(data.corr(),annot=True)
plt.title('understanding the correlation')
# Out:
# Text(0.5, 1.0, 'understanding the correlation')

# %%
sns.boxplot(data=data,x="IMDB rating",y="Year of Release")
plt.title('boxplot for rating vs year of release')
# Out:
# Text(0.5, 1.0, 'boxplot for rating vs year of release')

# %%
plt.figure(figsize=(12,12))
plt.title('Number of movies released per year recorded')
sns.countplot(y=data["Year of Release"])
plt.xticks(rotation=60)
plt.ylabel("year")
# Out:
# Text(0, 0.5, 'year')

# %%
sns.histplot(x=data["IMDB rating"],kde=True)
plt.title('histogram representing maximum IMDb rating count')
plt.xticks(rotation=90)
# Out:
# (array([8.2, 8.4, 8.6, 8.8, 9. , 9.2, 9.4, 9.6]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(5,5))
plt.xticks(rotation=90)
plt.title("a scatter plot")
sns.scatterplot(x="Year of Release",y="IMDB rating",data=data)
# Out:
# <AxesSubplot:title={'center':'a scatter plot'}, xlabel='Year of Release', ylabel='IMDB rating'>

# %%
rating_cnt=data["IMDB rating"].value_counts()

# %%
plt.figure(figsize=(12,6))
plt.title("Ratings ratio")
plt.pie(rating_cnt,labels=rating_cnt.index, autopct='%1.1f%%', startangle=180,labeldistance=1.15) 
plt.legend(loc="center right",bbox_to_anchor=(-1,1))
plt.show()

# %%
# Out:
# (array([1950., 1960., 1970., 1980., 1990., 2000., 2010., 2020., 2030.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
